# %%
from pubchem_search.browser import PubChemSearch

browser = PubChemSearch()

hits = browser.lookup_matching_smiles(
    smarts="[C;!$([c])]=[C;!$([c])]-[C;!$([c])]=[C;!$([c])]",
    limit=5,
    oversample=25,
    randomize=True,
    kind="ConnectivitySMILES",
)
hits
# Out:
# PubSearchResult(
#   kind='ConnectivitySMILES', limit=5, randomize=True, oversample=15
#   requested_cids=5, returned_smiles=5
#   smarts='[C;!$([c])]=[C;!$([c])]-[C;!$([c])]=[C;!$([c])]'
#   matching_smiles=
#      1. CC1=CC(=C(C(=C1C=CC(=CC=CC(=CC(=O)O)C)C)C)C)OC
#      2. CCC(C)C1C(CCC2(O1)CC3CC(O2)CC=C(C(C(C=CC=C4COC5C4(C(C=C(C5O)C)C(=O)O3)O)C)OC6CC(C(C(O6)C)OC7CC(C(C(O7)C)O)OC)OC)C)C
#      3. CC(=O)NC1CCC2=CC(=C(C(=C2C3=CC=C(C(=O)C=C13)OC)OC)OC)OC
#      4. CC(=CC=CC=C(C)C=CC=C(C)C(=O)OC1C(C(C(C(O1)COC2C(C(C(C(O2)CO)O)O)O)O)O)O)C=CC=C(C)C(=O)OC3C(C(C(C(O3)COC4C(C(C(C(O4)CO)O)O)O)O)O)O
#      5. C1C=C2C(=CC(=O)O2)C(O1)O
# )
