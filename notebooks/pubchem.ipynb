# %%
from pubchem_search.browser import PubChemSearch

browser = PubChemSearch()

hits = browser.lookup_matching_smiles(
    smarts="[C;X3;!$([C]-[c])](=[O;X1])[$([O;H1;X2]),$([O-;X1])]",
    limit=20,
    oversample=25,
    randomize=True,
    kind="ConnectivitySMILES",
)
hits
# Out:
# PubSearchResult(
#   kind='ConnectivitySMILES', limit=20, randomize=True, oversample=25
#   requested_cids=20, returned_smiles=20
#   smarts='[C;X3;!$([C]-[c])](=[O;X1])[$([O;H1;X2]),$([O-;X1])]'
#   matching_smiles=
#      1. CCCCCCCCC(=O)O
#      2. C1=CC=C2C(=C1)C(=CN2)CC(=O)O
#      3. CC1CCC2=C3N1C=C(C(=O)C3=CC(=C2)F)C(=O)O
#      4. C1=CC(=CC=C1CC(C(=O)O)N)O
#      5. CCCCCCCC(=O)O
#      6. C(=CC(=O)O)C(=O)O
#      7. CC(=O)O
#      8. CC1(C2CCC3(C(C2(CCC1OC4C(C(C(C(O4)C(=O)O)O)O)OC5C(C(C(C(O5)C(=O)O)O)O)O)C)C(=O)C=C6C3(CCC7(C6CC(CC7)(C)C(=O)O)C)C)C)C
#      9. CCCCCCCCCC(=O)O
#     10. C(C(C(=O)O)N)S
#     11. C(C(=O)O)N
#     12. C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2
#     13. CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C
#     14. C(CC(=O)O)CC(=O)O
#     15. CCCCCCCCC=CCCCCCCCC(=O)O
#     16. CC(C(=O)O)O
#     17. C(CC(=O)O)C(=O)O
#     18. CCCCCCCCCCCC(=O)O
#     19. C(C(C(=O)O)N)C(=O)O
#     20. C1=CC(=CC=C1C(=O)NC(CCC(=O)O)C(=O)O)NCC2=CN=C3C(=N2)C(=O)NC(=N3)N
# )
